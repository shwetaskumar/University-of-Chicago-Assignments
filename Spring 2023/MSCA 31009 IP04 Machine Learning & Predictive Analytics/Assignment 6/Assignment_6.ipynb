# %% [markdown]
# # ASSIGNMENT 6

# %% [markdown]
# ## Preparation

# %% [markdown]
# ### 2. Setup/import

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

from keras.utils import load_img, img_to_array

from sklearn.metrics import accuracy_score

import glob
from google.colab import drive
import os
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## 1. Data Processing:
# The train & test data is pretty clean in terms of image data, but we will need to do a bit of prep work to use in our model.

# %% [markdown]
# a) Use the "ImageDataGenerator()" class from keras.processing.image to build out an instance called "train_datagen" with the following parameters:
# - rescale = 1./255
# - shear_range = 0.2
# - zoom_range = 0.2
# - horizontal_flip = True

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip=True)

# %% [markdown]
# b) Then build your training set by using the method ".flow_from_directory()"
# - path (where training data is stored)
# - target_size = (64, 64)
# - batch_size = 32
# - class_mode = categorical

# %%
directory = 'gdrive/My Drive/dataset_train'
train_set = train_datagen.flow_from_directory(directory,
                                  target_size = (64, 64),
                                  batch_size = 32,
                                  class_mode = 'categorical')
# Out:
# Found 88 images belonging to 4 classes.

# %% [markdown]
# c) Take a look at your training set:
#
# - What is the image shape of each training observation?
# - How many total classes do we need to predict on?

# %%
print("Image shape:", train_set.image_shape)
print("Number of classes:", train_set.num_classes)
# Out:
# Image shape: (64, 64, 3)
# Number of classes: 4

# %% [markdown]
# # 2. Initial Classifier Build:
# Now use keras to build an initial image classifier with the following specifications.

# %% [markdown]
# - Create an instance of Sequential called "classifier"

# %%
classifier = Sequential()

# %% [markdown]
# - Add a Conv2D layer with the following parameters:
#     - filters = 32
#     - kernel_size = (3,3)
#     - input_shape = image shape found in part 1
#     - activation = relu

# %%
classifier.add(Conv2D(filters=32, kernel_size=(3,3), input_shape=train_set.image_shape, activation='relu'))

# %% [markdown]
# - Add a MaxPooling2D layer where pool_size = (2,2)

# %%
classifier.add(MaxPooling2D(pool_size=(2, 2)))

# %% [markdown]
# - Add another Conv2D layer:
#     - filters = 64
#     - kernel_size = (3,3)
#     - activation = relu

# %%
classifier.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu'))

# %% [markdown]
# - Add a MaxPooling2D layer where pool_size = (2,2)

# %%
classifier.add(MaxPooling2D(pool_size=(2, 2)))

# %% [markdown]
# - Add a Flatten layer

# %%
classifier.add(keras.layers.Flatten())

# %% [markdown]
# - Add a Dense layer
#     - units = 128
#     - activation = relu

# %%
classifier.add(keras.layers.Dense(units = 128, activation = 'relu'))

# %% [markdown]
# - Add a final Dense layer (this will output our probabilities):
#     - units = # of classes
#     - activation = softmax

# %%
classifier.add(Dense(units = train_set.num_classes, activation = 'softmax'))

# %% [markdown]
# - Compile with the following:
#     - optimize = adam
#     - loss = categorical cross entropy
#     - metric = accuracy

# %%
classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ## 3. Model Runs:
#
# This will be run various times with different numbers of steps_per_epoch and epochs.

# %% [markdown]
# a) Use .fit() with the training set. For the first run, use the following parameters:
# - steps_per_epoch = 3
# - epochs = 3

# %%
classifier.fit(train_set, steps_per_epoch=3, epochs=3)
# Out:
# Epoch 1/3
# 3/3 [==============================] - 4s 212ms/step - loss: 1.9468 - accuracy: 0.3409
# Epoch 2/3
# 3/3 [==============================] - 1s 319ms/step - loss: 1.1827 - accuracy: 0.5341
# Epoch 3/3
# 3/3 [==============================] - 1s 325ms/step - loss: 0.5965 - accuracy: 0.8864

# %% [markdown]
# b) save model to a file. An example is below:
# ```
# # save model
# classifier.save('my_model.h5')
# print("Saved model")
# ```

# %%
classifier.save('my_model.h5')
print("Saved model")
# Out:
# Saved model

# %% [markdown]
# c) Predict using the model built in step 2.

# %%
# returns a compiled model
# identical to the previous one
model = load_model('my_model.h5')
print("Loaded model from disk")

# test data path
img_dir = "gdrive/My Drive/dataset_test"

data_path = os.path.join(img_dir, '*g')
files = glob.glob(data_path)

# print the files in the dataset_test folder 
for f in files:
    print(f)

# make a prediction and add to results 
data = []
results = []
for f1 in files:
    img = load_img(f1, target_size = (64, 64))
    img = img_to_array(img)           # Convert the image to an array
    img = np.expand_dims(img, axis = 0)     # Add a fourth dimension to the image array to match input shape of the model
    data.append(img)
    result = model.predict(img)
    r = np.argmax(result, axis=1)
    results.append(r)

results
# Out:
# Loaded model from disk
# gdrive/My Drive/dataset_test/6051.png
# gdrive/My Drive/dataset_test/4053.png
# gdrive/My Drive/dataset_test/1053.png
# gdrive/My Drive/dataset_test/1022.png
# gdrive/My Drive/dataset_test/C033.png
# gdrive/My Drive/dataset_test/C014.png
# gdrive/My Drive/dataset_test/6023.png
# gdrive/My Drive/dataset_test/4011.png
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# [array([1]),
#  array([2]),
#  array([0]),
#  array([0]),
#  array([3]),
#  array([1]),
#  array([1]),
#  array([1])]

# %% [markdown]
# d) Determine accuracy.

# %%
# check category labels in training_set
train_set.class_indices
# Out:
# {'category 1': 0, 'category 2': 1, 'category 3': 2, 'category 4': 3}

# %%
test_label = [1, 2, 0, 0, 3, 3, 1, 2]

# calculate accuracy score
accuracy = accuracy_score(test_label, results)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.75

# %% [markdown]
# e) Run this process for the following combinations:
#
# * (steps_per_epoch: 1, epochs: 1)
# * (steps_per_epoch: 1, epochs: 2)
# * (steps_per_epoch: 1, epochs: 3)
# * (steps_per_epoch: 2, epochs: 4)
# * (steps_per_epoch: 2, epochs: 5)
# * (steps_per_epoch: 2, epochs: 6)
# * (steps_per_epoch: 3, epochs: 7)
# * (steps_per_epoch: 3, epochs: 8)
# * (steps_per_epoch: 5, epochs: 9)
# * (steps_per_epoch: 5, epochs: 10)

# %%
# def determine_acc(s, e, steps_list, epochs_list, accuracy_list, train_accuracy_list, history_list):
#     classifier = Sequential()
#     classifier.add(Conv2D(filters=32, kernel_size=(3,3), input_shape=train_set.image_shape, activation='relu'))
#     classifier.add(MaxPooling2D(pool_size=(2, 2)))
#     classifier.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
#     classifier.add(MaxPooling2D(pool_size=(2, 2)))
#     classifier.add(keras.layers.Flatten())
#     classifier.add(keras.layers.Dense(units = 128, activation = 'relu'))
#     classifier.add(Dense(units = train_set.num_classes, activation = 'softmax'))
#     classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

#     history = classifier.fit(train_set, steps_per_epoch = s, epochs = e)
#     model_name = 'Model_' + str(s) + '_' + str(e) + '.h5'
#     classifier.save(model_name)
#     print(train_set.class_indices)
#     print("Saved model: " + model_name)

#     model = load_model(model_name)
#     print("Loaded model from disk: " + model_name)

#     # make a prediction and add to results 
#     data = []
#     results = []
#     for f1 in files:
#         img = load_img(f1, target_size = (64, 64))
#         img = img_to_array(img)           # Convert the image to an array
#         img = np.expand_dims(img, axis = 0)     # Add a fourth dimension to the image array to match input shape of the model
#         data.append(img)
#         result = model.predict(img)
#         r = np.argmax(result, axis=1)
#         results.append(r)
    
#     print("The Loss = " + str(history.history['loss']))
#     accuracy = accuracy_score(test_label, results)
#     steps_list.append(s)
#     epochs_list.append(e)
#     accuracy_list.append(accuracy)
#     history_list.append(history.history['loss'][len(history.history['loss'])-1])
#     train_accuracy_list.append(history.history['accuracy'][len(history.history['accuracy'])-1])

#     return steps_list, epochs_list, accuracy_list, train_accuracy_list, history_list

# combinations = [(1, 1), (1,2), (1, 3), (2, 4), (2, 5), (2,6), (3, 7), (3, 8), (5, 9), (5, 10)]

# steps_list = []
# epochs_list = []
# accuracy_list = []
# history_list =[]
# train_accuracy_list = []

# for s, e in combinations:
#     steps_list, epochs_list, accuracy_list, train_accuracy_list, history_list = determine_acc(s, e, steps_list, epochs_list, accuracy_list, train_accuracy_list, history_list)
#     print()
#     print()

# %%
n_batch = 5
n_epochs = 5

combinations = [(1, 1), (1, 2), (1, 3), (2, 4), (2, 5), (2, 6), (3, 7), (3, 8), (5, 9), (5, 10)]

steps_list = []
epochs_list = []
accuracy_list = []
history_list =[]
train_accuracy_list = []

for s, e in combinations:
    print('Steps:', s, 'Epochs:', e)
    print('--------------')
    
    # fit the model using generator
    for epoch in range(e):
        print('Epoch', epoch)
        batches = 0
        for x_batch, y_batch in train_datagen.flow_from_directory(directory, target_size=(64, 64), batch_size = 32, class_mode = 'categorical', seed = 74):
            classifier = Sequential()
            classifier.add(Conv2D(filters=32, kernel_size=(3,3), input_shape=train_set.image_shape, activation='relu'))
            classifier.add(MaxPooling2D(pool_size=(2, 2)))
            classifier.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
            classifier.add(MaxPooling2D(pool_size=(2, 2)))
            classifier.add(keras.layers.Flatten())
            classifier.add(keras.layers.Dense(units = 128, activation = 'relu'))
            classifier.add(Dense(units = train_set.num_classes, activation = 'softmax'))
            classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
            history = classifier.fit(x_batch, y_batch, steps_per_epoch = s, epochs = e)
            batches += 1
            if batches >= n_batch:
                break

    # save model and update lists
    model_name = 'Model_' + str(s) + '_' + str(e) + '.h5'
    classifier.save(model_name)
    print('Saved model:', model_name)

    model = load_model(model_name)
    print("Loaded model from disk: " + model_name)

    # determine accuracy using test set
    data = []
    results = []
    for f1 in files:
        img = load_img(f1, target_size=(64, 64))
        img = img_to_array(img)
        img = np.expand_dims(img, axis=0)
        data.append(img)
        result = model.predict(img)
        r = np.argmax(result, axis=1)
        results.append(r)

    print("The Loss = " + str(history.history['loss']))
    accuracy = accuracy_score(test_label, results)
    steps_list.append(s)
    epochs_list.append(e)
    accuracy_list.append(accuracy)
    history_list.append(history.history['loss'][len(history.history['loss'])-1])
    train_accuracy_list.append(history.history['accuracy'][len(history.history['accuracy'])-1])

    print('Accuracy:', accuracy)
    print('--------------')

    print()
    print()
    
# create a dataframe from the lists
df = pd.DataFrame({
    'Steps': steps_list,
    'Epochs': epochs_list,
    'Accuracy': accuracy_list,
    'Train Loss': history_list,
    'Train Accuracy': train_accuracy_list
})
# Out:
# Steps: 1 Epochs: 1
# --------------
# Epoch 0
# Found 88 images belonging to 4 classes.
# 1/1 [==============================] - 2s 2s/step - loss: 1.4494 - accuracy: 0.0312
# 1/1 [==============================] - 2s 2s/step - loss: 1.3912 - accuracy: 0.2812
# 1/1 [==============================] - 2s 2s/step - loss: 1.4008 - accuracy: 0.2500
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_train_function.<locals>.train_function at 0x7f43d0149fc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step - loss: 1.4318 - accuracy: 0.1562
# WARNING:tensorflow:6 out of the last 14 calls to <function Model.make_train_function.<locals>.train_function at 0x7f43401865f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step - loss: 1.4270 - accuracy: 0.0312
# Saved model: Model_1_1.h5
# Loaded model from disk: Model_1_1.h5
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# The Loss = [1.4270329475402832]
# Accuracy: 0.25
# --------------
#
#
# Steps: 1 Epochs: 2
# --------------
# Epoch 0
# Found 88 images belonging to 4 classes.
# Epoch 1/2
# 1/1 [==============================] - 1s 1s/step - loss: 1.4295 - accuracy: 0.0312
# Epoch 2/2
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1191 - accuracy: 0.5625
# Epoch 1/2
# 1/1 [==============================] - 1s 1s/step - loss: 1.3731 - accuracy: 0.2812
# Epoch 2/2
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1274 - accuracy: 0.5000
# Epoch 1/2
# 1/1 [==============================] - 1s 1s/step - loss: 1.4115 - accuracy: 0.2917
# Epoch 2/2
# 1/1 [==============================] - 0s 11ms/step - loss: 2.3996 - accuracy: 0.3750
# Epoch 1/2
# 1/1 [==============================] - 1s 1s/step - loss: 1.3985 - accuracy: 0.1250
# Epoch 2/2
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0669 - accuracy: 0.5625
# Epoch 1/2
# 1/1 [==============================] - 1s 1s/step - loss: 1.3852 - accuracy: 0.1875
# Epoch 2/2
# 1/1 [==============================] - 0s 13ms/step - loss: 1.5630 - accuracy: 0.3125
# Epoch 1
# Found 88 images belonging to 4 classes.
# Epoch 1/2
# 1/1 [==============================] - 1s 1s/step - loss: 1.5365 - accuracy: 0.1250
# Epoch 2/2
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4377 - accuracy: 0.8125
# Epoch 1/2
# 1/1 [==============================] - 1s 1s/step - loss: 1.3654 - accuracy: 0.2500
# Epoch 2/2
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0485 - accuracy: 0.5312
# Epoch 1/2
# 1/1 [==============================] - 1s 1s/step - loss: 1.4155 - accuracy: 0.2083
# Epoch 2/2
# 1/1 [==============================] - 0s 10ms/step - loss: 1.9565 - accuracy: 0.3750
# Epoch 1/2
# 1/1 [==============================] - 2s 2s/step - loss: 1.4108 - accuracy: 0.2500
# Epoch 2/2
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1504 - accuracy: 0.3438
# Epoch 1/2
# 1/1 [==============================] - 1s 1s/step - loss: 1.3405 - accuracy: 0.5312
# Epoch 2/2
# 1/1 [==============================] - 0s 12ms/step - loss: 2.0999 - accuracy: 0.2500
# Saved model: Model_1_2.h5
# Loaded model from disk: Model_1_2.h5
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# The Loss = [1.3405447006225586, 2.0998644828796387]
# Accuracy: 0.25
# --------------
#
#
# Steps: 1 Epochs: 3
# --------------
# Epoch 0
# Found 88 images belonging to 4 classes.
# Epoch 1/3
# 1/1 [==============================] - 2s 2s/step - loss: 1.3744 - accuracy: 0.3750
# Epoch 2/3
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3818 - accuracy: 0.5312
# Epoch 3/3
# 1/1 [==============================] - 0s 13ms/step - loss: 0.9100 - accuracy: 0.5625
# Epoch 1/3
# 1/1 [==============================] - 2s 2s/step - loss: 1.3581 - accuracy: 0.2812
# Epoch 2/3
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1477 - accuracy: 0.6562
# Epoch 3/3
# 1/1 [==============================] - 0s 11ms/step - loss: 0.8776 - accuracy: 0.6875
# Epoch 1/3
# 1/1 [==============================] - 1s 1s/step - loss: 1.4048 - accuracy: 0.2500
# Epoch 2/3
# 1/1 [==============================] - 0s 11ms/step - loss: 2.0093 - accuracy: 0.3750
# Epoch 3/3
# 1/1 [==============================] - 0s 10ms/step - loss: 0.9580 - accuracy: 0.5833
# Epoch 1/3
# 1/1 [==============================] - 1s 1s/step - loss: 1.4118 - accuracy: 0.3125
# Epoch 2/3
# 1/1 [==============================] - 0s 11ms/step - loss: 2.3728 - accuracy: 0.3125
# Epoch 3/3
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4862 - accuracy: 0.3438
# Epoch 1/3
# 1/1 [==============================] - 1s 1s/step - loss: 1.3650 - accuracy: 0.2500
# Epoch 2/3
# 1/1 [==============================] - 0s 11ms/step - loss: 2.2417 - accuracy: 0.3125
# Epoch 3/3
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2402 - accuracy: 0.3750
# Epoch 1
# Found 88 images belonging to 4 classes.
# Epoch 1/3
# 1/1 [==============================] - 1s 1s/step - loss: 1.3891 - accuracy: 0.2812
# Epoch 2/3
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4071 - accuracy: 0.3125
# Epoch 3/3
# 1/1 [==============================] - 0s 11ms/step - loss: 0.9369 - accuracy: 0.5938
# Epoch 1/3
# 1/1 [==============================] - 1s 1s/step - loss: 1.3815 - accuracy: 0.2812
# Epoch 2/3
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3741 - accuracy: 0.4375
# Epoch 3/3
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4359 - accuracy: 0.4375
# Epoch 1/3
# 1/1 [==============================] - 1s 1s/step - loss: 1.3855 - accuracy: 0.0833
# Epoch 2/3
# 1/1 [==============================] - 0s 12ms/step - loss: 1.7293 - accuracy: 0.3750
# Epoch 3/3
# 1/1 [==============================] - 0s 11ms/step - loss: 0.8831 - accuracy: 0.5417
# Epoch 1/3
# 1/1 [==============================] - 2s 2s/step - loss: 1.3944 - accuracy: 0.3125
# Epoch 2/3
# 1/1 [==============================] - 0s 14ms/step - loss: 1.3470 - accuracy: 0.6250
# Epoch 3/3
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7640 - accuracy: 0.8438
# Epoch 1/3
# 1/1 [==============================] - 1s 1s/step - loss: 1.4229 - accuracy: 0.2188
# Epoch 2/3
# 1/1 [==============================] - 0s 12ms/step - loss: 1.6811 - accuracy: 0.3125
# Epoch 3/3
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2958 - accuracy: 0.2500
# Epoch 2
# Found 88 images belonging to 4 classes.
# Epoch 1/3
# 1/1 [==============================] - 1s 1s/step - loss: 1.4653 - accuracy: 0.1250
# Epoch 2/3
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4979 - accuracy: 0.5625
# Epoch 3/3
# 1/1 [==============================] - 0s 11ms/step - loss: 1.9438 - accuracy: 0.2812
# Epoch 1/3
# 1/1 [==============================] - 1s 1s/step - loss: 1.3657 - accuracy: 0.2812
# Epoch 2/3
# 1/1 [==============================] - 0s 12ms/step - loss: 1.8790 - accuracy: 0.2812
# Epoch 3/3
# 1/1 [==============================] - 0s 11ms/step - loss: 0.9544 - accuracy: 0.4688
# Epoch 1/3
# 1/1 [==============================] - 1s 1s/step - loss: 1.4708 - accuracy: 0.2083
# Epoch 2/3
# 1/1 [==============================] - 0s 11ms/step - loss: 2.5465 - accuracy: 0.3750
# Epoch 3/3
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3187 - accuracy: 0.3750
# Epoch 1/3
# 1/1 [==============================] - 1s 1s/step - loss: 1.4246 - accuracy: 0.3438
# Epoch 2/3
# 1/1 [==============================] - 0s 12ms/step - loss: 2.5879 - accuracy: 0.3125
# Epoch 3/3
# 1/1 [==============================] - 0s 11ms/step - loss: 1.2800 - accuracy: 0.4375
# Epoch 1/3
# 1/1 [==============================] - 1s 1s/step - loss: 1.4203 - accuracy: 0.2500
# Epoch 2/3
# 1/1 [==============================] - 0s 12ms/step - loss: 1.7082 - accuracy: 0.3125
# Epoch 3/3
# 1/1 [==============================] - 0s 11ms/step - loss: 0.9682 - accuracy: 0.5312
# Saved model: Model_1_3.h5
# Loaded model from disk: Model_1_3.h5
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# The Loss = [1.420288324356079, 1.7081656455993652, 0.9682353734970093]
# Accuracy: 0.625
# --------------
#
#
# Steps: 2 Epochs: 4
# --------------
# Epoch 0
# Found 88 images belonging to 4 classes.
# Epoch 1/4
# 2/2 [==============================] - 2s 9ms/step - loss: 1.5615 - accuracy: 0.1875
# Epoch 2/4
# 2/2 [==============================] - 0s 8ms/step - loss: 1.2183 - accuracy: 0.5000
# Epoch 3/4
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7960 - accuracy: 0.7500
# Epoch 4/4
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4073 - accuracy: 0.9062
# Epoch 1/4
# 2/2 [==============================] - 1s 10ms/step - loss: 1.8766 - accuracy: 0.0625
# Epoch 2/4
# 2/2 [==============================] - 0s 8ms/step - loss: 1.3360 - accuracy: 0.4375
# Epoch 3/4
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0733 - accuracy: 0.6562
# Epoch 4/4
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7937 - accuracy: 0.9062
# Epoch 1/4
# 2/2 [==============================] - 2s 10ms/step - loss: 3.3787 - accuracy: 0.1667
# Epoch 2/4
# 2/2 [==============================] - 0s 8ms/step - loss: 1.6796 - accuracy: 0.2917
# Epoch 3/4
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1633 - accuracy: 0.5000
# Epoch 4/4
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8497 - accuracy: 1.0000
# Epoch 1/4
# 2/2 [==============================] - 1s 9ms/step - loss: 2.1322 - accuracy: 0.2188
# Epoch 2/4
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1325 - accuracy: 0.5000
# Epoch 3/4
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8249 - accuracy: 0.7188
# Epoch 4/4
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5566 - accuracy: 0.9062
# Epoch 1/4
# 2/2 [==============================] - 1s 12ms/step - loss: 2.1456 - accuracy: 0.2500
# Epoch 2/4
# 2/2 [==============================] - 0s 7ms/step - loss: 1.3833 - accuracy: 0.4688
# Epoch 3/4
# 2/2 [==============================] - 0s 13ms/step - loss: 0.8705 - accuracy: 0.8750
# Epoch 4/4
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6472 - accuracy: 0.8438
# Epoch 1
# Found 88 images belonging to 4 classes.
# Epoch 1/4
# 2/2 [==============================] - 2s 11ms/step - loss: 1.5878 - accuracy: 0.2812
# Epoch 2/4
# 2/2 [==============================] - 0s 9ms/step - loss: 1.5130 - accuracy: 0.5625
# Epoch 3/4
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6700 - accuracy: 0.8125
# Epoch 4/4
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5006 - accuracy: 0.8750
# Epoch 1/4
# 2/2 [==============================] - 1s 10ms/step - loss: 1.6488 - accuracy: 0.1875
# Epoch 2/4
# 2/2 [==============================] - 0s 9ms/step - loss: 1.2758 - accuracy: 0.3750
# Epoch 3/4
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8755 - accuracy: 0.6875
# Epoch 4/4
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4924 - accuracy: 0.9688
# Epoch 1/4
# 2/2 [==============================] - 1s 9ms/step - loss: 1.8243 - accuracy: 0.1667
# Epoch 2/4
# 2/2 [==============================] - 0s 7ms/step - loss: 1.4942 - accuracy: 0.4583
# Epoch 3/4
# 2/2 [==============================] - 0s 7ms/step - loss: 1.0773 - accuracy: 0.5833
# Epoch 4/4
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6315 - accuracy: 0.8333
# Epoch 1/4
# 2/2 [==============================] - 1s 10ms/step - loss: 2.4244 - accuracy: 0.2188
# Epoch 2/4
# 2/2 [==============================] - 0s 8ms/step - loss: 1.4184 - accuracy: 0.1562
# Epoch 3/4
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9900 - accuracy: 0.6562
# Epoch 4/4
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6040 - accuracy: 0.7812
# Epoch 1/4
# 2/2 [==============================] - 1s 9ms/step - loss: 1.4373 - accuracy: 0.2188
# Epoch 2/4
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1608 - accuracy: 0.4688
# Epoch 3/4
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7124 - accuracy: 0.9688
# Epoch 4/4
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4432 - accuracy: 0.8750
# Epoch 2
# Found 88 images belonging to 4 classes.
# Epoch 1/4
# 2/2 [==============================] - 2s 10ms/step - loss: 2.0165 - accuracy: 0.1562
# Epoch 2/4
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1709 - accuracy: 0.6250
# Epoch 3/4
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8919 - accuracy: 0.8438
# Epoch 4/4
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6082 - accuracy: 0.9688
# Epoch 1/4
# 2/2 [==============================] - 1s 11ms/step - loss: 1.9455 - accuracy: 0.2500
# Epoch 2/4
# 2/2 [==============================] - 0s 9ms/step - loss: 1.1021 - accuracy: 0.5625
# Epoch 3/4
# 2/2 [==============================] - 0s 9ms/step - loss: 0.9983 - accuracy: 0.6250
# Epoch 4/4
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6909 - accuracy: 0.8438
# Epoch 1/4
# 2/2 [==============================] - 1s 9ms/step - loss: 1.6860 - accuracy: 0.3333
# Epoch 2/4
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9063 - accuracy: 0.6667
# Epoch 3/4
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5822 - accuracy: 0.9583
# Epoch 4/4
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2678 - accuracy: 1.0000
# Epoch 1/4
# 2/2 [==============================] - 1s 9ms/step - loss: 2.4971 - accuracy: 0.1562
# Epoch 2/4
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1221 - accuracy: 0.6562
# Epoch 3/4
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0544 - accuracy: 0.6250
# Epoch 4/4
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7265 - accuracy: 0.9062
# Epoch 1/4
# 2/2 [==============================] - 1s 10ms/step - loss: 1.6487 - accuracy: 0.4688
# Epoch 2/4
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1203 - accuracy: 0.5938
# Epoch 3/4
# 2/2 [==============================] - 0s 7ms/step - loss: 0.8122 - accuracy: 0.8438
# Epoch 4/4
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4612 - accuracy: 0.9375
# Epoch 3
# Found 88 images belonging to 4 classes.
# Epoch 1/4
# 2/2 [==============================] - 1s 10ms/step - loss: 1.5046 - accuracy: 0.4062
# Epoch 2/4
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1725 - accuracy: 0.3438
# Epoch 3/4
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5886 - accuracy: 0.8438
# Epoch 4/4
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3694 - accuracy: 0.9062
# Epoch 1/4
# 2/2 [==============================] - 1s 10ms/step - loss: 1.4580 - accuracy: 0.1875
# Epoch 2/4
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1306 - accuracy: 0.4062
# Epoch 3/4
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6862 - accuracy: 0.9062
# Epoch 4/4
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4236 - accuracy: 0.9688
# Epoch 1/4
# 2/2 [==============================] - 1s 10ms/step - loss: 1.2706 - accuracy: 0.3333
# Epoch 2/4
# 2/2 [==============================] - 0s 7ms/step - loss: 1.1646 - accuracy: 0.5417
# Epoch 3/4
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3892 - accuracy: 0.9583
# Epoch 4/4
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1802 - accuracy: 1.0000
# Epoch 1/4
# 2/2 [==============================] - 1s 10ms/step - loss: 1.9095 - accuracy: 0.2812
# Epoch 2/4
# 2/2 [==============================] - 0s 9ms/step - loss: 0.8629 - accuracy: 0.6875
# Epoch 3/4
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.9062
# Epoch 4/4
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4019 - accuracy: 0.9375
# Epoch 1/4
# 2/2 [==============================] - 1s 10ms/step - loss: 1.5729 - accuracy: 0.2500
# Epoch 2/4
# 2/2 [==============================] - 0s 8ms/step - loss: 1.8385 - accuracy: 0.3125
# Epoch 3/4
# 2/2 [==============================] - 0s 7ms/step - loss: 1.0171 - accuracy: 0.6562
# Epoch 4/4
# 2/2 [==============================] - 0s 7ms/step - loss: 0.8012 - accuracy: 0.7812
# Saved model: Model_2_4.h5
# Loaded model from disk: Model_2_4.h5
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# The Loss = [1.5728554725646973, 1.8385165929794312, 1.0171040296554565, 0.8012280464172363]
# Accuracy: 0.5
# --------------
#
#
# Steps: 2 Epochs: 5
# --------------
# Epoch 0
# Found 88 images belonging to 4 classes.
# Epoch 1/5
# 2/2 [==============================] - 1s 10ms/step - loss: 1.9845 - accuracy: 0.2812
# Epoch 2/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9513 - accuracy: 0.6875
# Epoch 3/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7837 - accuracy: 0.6562
# Epoch 4/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3998 - accuracy: 0.9375
# Epoch 5/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2718 - accuracy: 0.9688
# Epoch 1/5
# 2/2 [==============================] - 1s 10ms/step - loss: 1.7884 - accuracy: 0.2500
# Epoch 2/5
# 2/2 [==============================] - 0s 9ms/step - loss: 1.4115 - accuracy: 0.4062
# Epoch 3/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8624 - accuracy: 0.6875
# Epoch 4/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6921 - accuracy: 0.8438
# Epoch 5/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4833 - accuracy: 0.9375
# Epoch 1/5
# 2/2 [==============================] - 1s 9ms/step - loss: 2.5406 - accuracy: 0.1667
# Epoch 2/5
# 2/2 [==============================] - 0s 7ms/step - loss: 1.3313 - accuracy: 0.5000
# Epoch 3/5
# 2/2 [==============================] - 0s 9ms/step - loss: 0.9612 - accuracy: 0.5833
# Epoch 4/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7332 - accuracy: 1.0000
# Epoch 5/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4303 - accuracy: 1.0000
# Epoch 1/5
# 2/2 [==============================] - 1s 10ms/step - loss: 2.1678 - accuracy: 0.1562
# Epoch 2/5
# 2/2 [==============================] - 0s 7ms/step - loss: 1.1706 - accuracy: 0.5938
# Epoch 3/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9615 - accuracy: 0.7188
# Epoch 4/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6803 - accuracy: 0.9375
# Epoch 5/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4611 - accuracy: 0.9375
# Epoch 1/5
# 2/2 [==============================] - 2s 10ms/step - loss: 2.4024 - accuracy: 0.2188
# Epoch 2/5
# 2/2 [==============================] - 0s 10ms/step - loss: 1.5181 - accuracy: 0.3750
# Epoch 3/5
# 2/2 [==============================] - 0s 9ms/step - loss: 1.0571 - accuracy: 0.5938
# Epoch 4/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.8421 - accuracy: 0.8125
# Epoch 5/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6217 - accuracy: 0.8125
# Epoch 1
# Found 88 images belonging to 4 classes.
# Epoch 1/5
# 2/2 [==============================] - 1s 11ms/step - loss: 1.9219 - accuracy: 0.4375
# Epoch 2/5
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1630 - accuracy: 0.4688
# Epoch 3/5
# 2/2 [==============================] - 0s 9ms/step - loss: 0.8585 - accuracy: 0.5938
# Epoch 4/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3961 - accuracy: 0.9375
# Epoch 5/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3030 - accuracy: 0.9375
# Epoch 1/5
# 2/2 [==============================] - 1s 10ms/step - loss: 1.6705 - accuracy: 0.1562
# Epoch 2/5
# 2/2 [==============================] - 0s 9ms/step - loss: 1.1792 - accuracy: 0.6250
# Epoch 3/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7613 - accuracy: 0.8438
# Epoch 4/5
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4820 - accuracy: 0.9375
# Epoch 5/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2815 - accuracy: 1.0000
# Epoch 1/5
# 2/2 [==============================] - 1s 9ms/step - loss: 2.7620 - accuracy: 0.2917
# Epoch 2/5
# 2/2 [==============================] - 0s 8ms/step - loss: 1.4215 - accuracy: 0.2917
# Epoch 3/5
# 2/2 [==============================] - 0s 7ms/step - loss: 1.2714 - accuracy: 0.4167
# Epoch 4/5
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9527 - accuracy: 0.7917
# Epoch 5/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7099 - accuracy: 0.7500
# Epoch 1/5
# 2/2 [==============================] - 1s 10ms/step - loss: 2.2682 - accuracy: 0.2188
# Epoch 2/5
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1060 - accuracy: 0.5625
# Epoch 3/5
# 2/2 [==============================] - 0s 9ms/step - loss: 0.9707 - accuracy: 0.5938
# Epoch 4/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.8110 - accuracy: 0.9062
# Epoch 5/5
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5550 - accuracy: 0.9688
# Epoch 1/5
# 2/2 [==============================] - 1s 10ms/step - loss: 3.0349 - accuracy: 0.2812
# Epoch 2/5
# 2/2 [==============================] - 0s 10ms/step - loss: 1.2974 - accuracy: 0.4375
# Epoch 3/5
# 2/2 [==============================] - 0s 9ms/step - loss: 1.1908 - accuracy: 0.6875
# Epoch 4/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7447 - accuracy: 0.6562
# Epoch 5/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5509 - accuracy: 0.8750
# Epoch 2
# Found 88 images belonging to 4 classes.
# Epoch 1/5
# 2/2 [==============================] - 1s 11ms/step - loss: 2.2763 - accuracy: 0.1250
# Epoch 2/5
# 2/2 [==============================] - 0s 11ms/step - loss: 1.4128 - accuracy: 0.4688
# Epoch 3/5
# 2/2 [==============================] - 0s 9ms/step - loss: 1.0848 - accuracy: 0.3750
# Epoch 4/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8679 - accuracy: 0.6562
# Epoch 5/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6082 - accuracy: 0.9688
# Epoch 1/5
# 2/2 [==============================] - 1s 10ms/step - loss: 2.8933 - accuracy: 0.0938
# Epoch 2/5
# 2/2 [==============================] - 0s 8ms/step - loss: 1.2830 - accuracy: 0.3125
# Epoch 3/5
# 2/2 [==============================] - 0s 8ms/step - loss: 1.3623 - accuracy: 0.6250
# Epoch 4/5
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1080 - accuracy: 0.6875
# Epoch 5/5
# 2/2 [==============================] - 0s 9ms/step - loss: 0.8809 - accuracy: 0.7812
# Epoch 1/5
# 2/2 [==============================] - 1s 10ms/step - loss: 1.6250 - accuracy: 0.1667
# Epoch 2/5
# 2/2 [==============================] - 0s 7ms/step - loss: 1.0802 - accuracy: 0.4583
# Epoch 3/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6201 - accuracy: 0.9583
# Epoch 4/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3620 - accuracy: 1.0000
# Epoch 5/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1638 - accuracy: 1.0000
# Epoch 1/5
# 2/2 [==============================] - 1s 10ms/step - loss: 1.8050 - accuracy: 0.1250
# Epoch 2/5
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1222 - accuracy: 0.5625
# Epoch 3/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7940 - accuracy: 0.7500
# Epoch 4/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4400 - accuracy: 1.0000
# Epoch 5/5
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2607 - accuracy: 0.9688
# Epoch 1/5
# 2/2 [==============================] - 1s 11ms/step - loss: 1.7541 - accuracy: 0.2812
# Epoch 2/5
# 2/2 [==============================] - 0s 7ms/step - loss: 1.2672 - accuracy: 0.4688
# Epoch 3/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9070 - accuracy: 0.7500
# Epoch 4/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6573 - accuracy: 0.8125
# Epoch 5/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4223 - accuracy: 0.9062
# Epoch 3
# Found 88 images belonging to 4 classes.
# Epoch 1/5
# 2/2 [==============================] - 1s 10ms/step - loss: 1.3655 - accuracy: 0.4688
# Epoch 2/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8101 - accuracy: 0.6250
# Epoch 3/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5549 - accuracy: 0.9062
# Epoch 4/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2675 - accuracy: 0.9375
# Epoch 5/5
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1528 - accuracy: 1.0000
# Epoch 1/5
# 2/2 [==============================] - 1s 11ms/step - loss: 1.4094 - accuracy: 0.2188
# Epoch 2/5
# 2/2 [==============================] - 0s 10ms/step - loss: 1.2722 - accuracy: 0.3438
# Epoch 3/5
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7982 - accuracy: 0.7812
# Epoch 4/5
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6139 - accuracy: 0.9688
# Epoch 5/5
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2846 - accuracy: 0.9375
# Epoch 1/5
# 2/2 [==============================] - 1s 11ms/step - loss: 2.0108 - accuracy: 0.2083
# Epoch 2/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9933 - accuracy: 0.5833
# Epoch 3/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7776 - accuracy: 0.8750
# Epoch 4/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4941 - accuracy: 1.0000
# Epoch 5/5
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2291 - accuracy: 1.0000
# Epoch 1/5
# 2/2 [==============================] - 2s 10ms/step - loss: 2.1208 - accuracy: 0.2188
# Epoch 2/5
# 2/2 [==============================] - 0s 8ms/step - loss: 2.2128 - accuracy: 0.4375
# Epoch 3/5
# 2/2 [==============================] - 0s 9ms/step - loss: 0.9813 - accuracy: 0.6562
# Epoch 4/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7756 - accuracy: 0.7500
# Epoch 5/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5600 - accuracy: 0.9375
# Epoch 1/5
# 2/2 [==============================] - 1s 9ms/step - loss: 2.0862 - accuracy: 0.2500
# Epoch 2/5
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0251 - accuracy: 0.5000
# Epoch 3/5
# 2/2 [==============================] - 0s 11ms/step - loss: 0.9470 - accuracy: 0.5312
# Epoch 4/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6043 - accuracy: 0.8438
# Epoch 5/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3518 - accuracy: 0.9375
# Epoch 4
# Found 88 images belonging to 4 classes.
# Epoch 1/5
# 2/2 [==============================] - 1s 10ms/step - loss: 1.9892 - accuracy: 0.2500
# Epoch 2/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9981 - accuracy: 0.6875
# Epoch 3/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8034 - accuracy: 0.8438
# Epoch 4/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4549 - accuracy: 0.9375
# Epoch 5/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2219 - accuracy: 1.0000
# Epoch 1/5
# 2/2 [==============================] - 1s 10ms/step - loss: 2.2937 - accuracy: 0.3125
# Epoch 2/5
# 2/2 [==============================] - 0s 9ms/step - loss: 1.6390 - accuracy: 0.4375
# Epoch 3/5
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1952 - accuracy: 0.5938
# Epoch 4/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6554 - accuracy: 0.9062
# Epoch 5/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5167 - accuracy: 0.8438
# Epoch 1/5
# 2/2 [==============================] - 1s 10ms/step - loss: 2.0653 - accuracy: 0.3750
# Epoch 2/5
# 2/2 [==============================] - 0s 7ms/step - loss: 1.1687 - accuracy: 0.4167
# Epoch 3/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8147 - accuracy: 0.7083
# Epoch 4/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4516 - accuracy: 1.0000
# Epoch 5/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2659 - accuracy: 1.0000
# Epoch 1/5
# 2/2 [==============================] - 1s 12ms/step - loss: 2.0734 - accuracy: 0.2188
# Epoch 2/5
# 2/2 [==============================] - 0s 10ms/step - loss: 1.2171 - accuracy: 0.4375
# Epoch 3/5
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6486 - accuracy: 0.9688
# Epoch 4/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4468 - accuracy: 0.9375
# Epoch 5/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2361 - accuracy: 0.9688
# Epoch 1/5
# 2/2 [==============================] - 1s 11ms/step - loss: 1.6529 - accuracy: 0.2500
# Epoch 2/5
# 2/2 [==============================] - 0s 7ms/step - loss: 1.2336 - accuracy: 0.4688
# Epoch 3/5
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8740 - accuracy: 0.8438
# Epoch 4/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5706 - accuracy: 0.9062
# Epoch 5/5
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3760 - accuracy: 0.9062
# Saved model: Model_2_5.h5
# Loaded model from disk: Model_2_5.h5
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# The Loss = [1.6529192924499512, 1.233640193939209, 0.8739954233169556, 0.5706182718276978, 0.3759876489639282]
# Accuracy: 0.875
# --------------
#
#
# Steps: 2 Epochs: 6
# --------------
# Epoch 0
# Found 88 images belonging to 4 classes.
# Epoch 1/6
# 2/2 [==============================] - 1s 10ms/step - loss: 1.4712 - accuracy: 0.1250
# Epoch 2/6
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0680 - accuracy: 0.5625
# Epoch 3/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6041 - accuracy: 0.9062
# Epoch 4/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4075 - accuracy: 0.8750
# Epoch 5/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1757 - accuracy: 0.9688
# Epoch 6/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1140 - accuracy: 0.9688
# Epoch 1/6
# 2/2 [==============================] - 1s 12ms/step - loss: 2.0876 - accuracy: 0.1250
# Epoch 2/6
# 2/2 [==============================] - 0s 9ms/step - loss: 1.4385 - accuracy: 0.5312
# Epoch 3/6
# 2/2 [==============================] - 0s 10ms/step - loss: 1.0833 - accuracy: 0.6562
# Epoch 4/6
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7929 - accuracy: 0.8125
# Epoch 5/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5251 - accuracy: 0.9375
# Epoch 6/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2827 - accuracy: 0.9688
# Epoch 1/6
# 2/2 [==============================] - 1s 10ms/step - loss: 1.7445 - accuracy: 0.2500
# Epoch 2/6
# 2/2 [==============================] - 0s 11ms/step - loss: 1.4204 - accuracy: 0.5000
# Epoch 3/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8152 - accuracy: 0.6667
# Epoch 4/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4270 - accuracy: 1.0000
# Epoch 5/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2612 - accuracy: 1.0000
# Epoch 6/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1327 - accuracy: 1.0000
# Epoch 1/6
# 2/2 [==============================] - 1s 10ms/step - loss: 1.5785 - accuracy: 0.1562
# Epoch 2/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.9956 - accuracy: 0.7500
# Epoch 3/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6630 - accuracy: 1.0000
# Epoch 4/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3525 - accuracy: 0.9688
# Epoch 5/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1497 - accuracy: 1.0000
# Epoch 6/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0659 - accuracy: 1.0000
# Epoch 1/6
# 2/2 [==============================] - 1s 13ms/step - loss: 2.4994 - accuracy: 0.2500
# Epoch 2/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9962 - accuracy: 0.5000
# Epoch 3/6
# 2/2 [==============================] - 0s 15ms/step - loss: 0.9829 - accuracy: 0.6562
# Epoch 4/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5201 - accuracy: 0.9375
# Epoch 5/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4560 - accuracy: 0.9062
# Epoch 6/6
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3163 - accuracy: 0.9375
# Epoch 1
# Found 88 images belonging to 4 classes.
# Epoch 1/6
# 2/2 [==============================] - 1s 10ms/step - loss: 1.3317 - accuracy: 0.4062
# Epoch 2/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8417 - accuracy: 0.6250
# Epoch 3/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4171 - accuracy: 0.9375
# Epoch 4/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1880 - accuracy: 0.9688
# Epoch 5/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0931 - accuracy: 0.9688
# Epoch 6/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0418 - accuracy: 1.0000
# Epoch 1/6
# 2/2 [==============================] - 1s 10ms/step - loss: 1.9623 - accuracy: 0.2188
# Epoch 2/6
# 2/2 [==============================] - 0s 9ms/step - loss: 1.1719 - accuracy: 0.3750
# Epoch 3/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.9906 - accuracy: 0.4688
# Epoch 4/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6413 - accuracy: 0.9062
# Epoch 5/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3725 - accuracy: 0.9688
# Epoch 6/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1723 - accuracy: 1.0000
# Epoch 1/6
# 2/2 [==============================] - 2s 10ms/step - loss: 1.7900 - accuracy: 0.2917
# Epoch 2/6
# 2/2 [==============================] - 0s 11ms/step - loss: 0.9243 - accuracy: 0.6667
# Epoch 3/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5428 - accuracy: 1.0000
# Epoch 4/6
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3055 - accuracy: 1.0000
# Epoch 5/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1081 - accuracy: 1.0000
# Epoch 6/6
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0400 - accuracy: 1.0000
# Epoch 1/6
# 2/2 [==============================] - 1s 10ms/step - loss: 3.0992 - accuracy: 0.2812
# Epoch 2/6
# 2/2 [==============================] - 0s 9ms/step - loss: 1.1844 - accuracy: 0.4062
# Epoch 3/6
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0989 - accuracy: 0.4688
# Epoch 4/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7755 - accuracy: 0.7188
# Epoch 5/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4768 - accuracy: 0.9688
# Epoch 6/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2901 - accuracy: 1.0000
# Epoch 1/6
# 2/2 [==============================] - 1s 9ms/step - loss: 2.4271 - accuracy: 0.2812
# Epoch 2/6
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1742 - accuracy: 0.5000
# Epoch 3/6
# 2/2 [==============================] - 0s 9ms/step - loss: 1.0615 - accuracy: 0.5938
# Epoch 4/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7303 - accuracy: 0.7188
# Epoch 5/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5299 - accuracy: 0.8438
# Epoch 6/6
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3742 - accuracy: 0.9062
# Epoch 2
# Found 88 images belonging to 4 classes.
# Epoch 1/6
# 2/2 [==============================] - 2s 11ms/step - loss: 1.2963 - accuracy: 0.3750
# Epoch 2/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.8246 - accuracy: 0.6875
# Epoch 3/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3728 - accuracy: 0.8750
# Epoch 4/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2085 - accuracy: 0.9688
# Epoch 5/6
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1029 - accuracy: 0.9688
# Epoch 6/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0358 - accuracy: 1.0000
# Epoch 1/6
# 2/2 [==============================] - 1s 10ms/step - loss: 1.7430 - accuracy: 0.2500
# Epoch 2/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9828 - accuracy: 0.5625
# Epoch 3/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7286 - accuracy: 0.7812
# Epoch 4/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3927 - accuracy: 0.9062
# Epoch 5/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2595 - accuracy: 0.9688
# Epoch 6/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1328 - accuracy: 0.9375
# Epoch 1/6
# 2/2 [==============================] - 1s 10ms/step - loss: 2.1578 - accuracy: 0.2500
# Epoch 2/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.9560 - accuracy: 0.8333
# Epoch 3/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9207 - accuracy: 0.6250
# Epoch 4/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4372 - accuracy: 1.0000
# Epoch 5/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3121 - accuracy: 0.9583
# Epoch 6/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1148 - accuracy: 1.0000
# Epoch 1/6
# 2/2 [==============================] - 1s 11ms/step - loss: 2.0858 - accuracy: 0.1250
# Epoch 2/6
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0847 - accuracy: 0.5625
# Epoch 3/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.8340 - accuracy: 0.8750
# Epoch 4/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6420 - accuracy: 0.9062
# Epoch 5/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4368 - accuracy: 0.9375
# Epoch 6/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2514 - accuracy: 1.0000
# Epoch 1/6
# 2/2 [==============================] - 1s 9ms/step - loss: 2.3343 - accuracy: 0.3125
# Epoch 2/6
# 2/2 [==============================] - 0s 9ms/step - loss: 1.2212 - accuracy: 0.4688
# Epoch 3/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9968 - accuracy: 0.5625
# Epoch 4/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5435 - accuracy: 0.9062
# Epoch 5/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4078 - accuracy: 0.9062
# Epoch 6/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2534 - accuracy: 0.9688
# Epoch 3
# Found 88 images belonging to 4 classes.
# Epoch 1/6
# 2/2 [==============================] - 1s 10ms/step - loss: 1.3906 - accuracy: 0.2188
# Epoch 2/6
# 2/2 [==============================] - 0s 10ms/step - loss: 0.8501 - accuracy: 0.8125
# Epoch 3/6
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4185 - accuracy: 0.9375
# Epoch 4/6
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2010 - accuracy: 0.9688
# Epoch 5/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0838 - accuracy: 1.0000
# Epoch 6/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0368 - accuracy: 1.0000
# Epoch 1/6
# 2/2 [==============================] - 1s 10ms/step - loss: 2.6158 - accuracy: 0.2188
# Epoch 2/6
# 2/2 [==============================] - 0s 11ms/step - loss: 1.5670 - accuracy: 0.4375
# Epoch 3/6
# 2/2 [==============================] - 0s 8ms/step - loss: 1.2936 - accuracy: 0.4375
# Epoch 4/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9745 - accuracy: 0.6562
# Epoch 5/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6085 - accuracy: 0.9375
# Epoch 6/6
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4766 - accuracy: 0.8750
# Epoch 1/6
# 2/2 [==============================] - 2s 12ms/step - loss: 1.8749 - accuracy: 0.2083
# Epoch 2/6
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1842 - accuracy: 0.5417
# Epoch 3/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6256 - accuracy: 0.7500
# Epoch 4/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4375 - accuracy: 0.9583
# Epoch 5/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1900 - accuracy: 1.0000
# Epoch 6/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1149 - accuracy: 1.0000
# Epoch 1/6
# 2/2 [==============================] - 1s 10ms/step - loss: 1.4455 - accuracy: 0.4375
# Epoch 2/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9266 - accuracy: 0.6875
# Epoch 3/6
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4817 - accuracy: 0.9375
# Epoch 4/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2288 - accuracy: 0.9688
# Epoch 5/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1023 - accuracy: 1.0000
# Epoch 6/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0359 - accuracy: 1.0000
# Epoch 1/6
# 2/2 [==============================] - 1s 10ms/step - loss: 2.2585 - accuracy: 0.2188
# Epoch 2/6
# 2/2 [==============================] - 0s 8ms/step - loss: 1.7002 - accuracy: 0.5000
# Epoch 3/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9957 - accuracy: 0.6562
# Epoch 4/6
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7854 - accuracy: 0.9062
# Epoch 5/6
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6273 - accuracy: 0.8438
# Epoch 6/6
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4221 - accuracy: 0.9062
# Epoch 4
# Found 88 images belonging to 4 classes.
# Epoch 1/6
# 2/2 [==============================] - 1s 10ms/step - loss: 1.7292 - accuracy: 0.3750
# Epoch 2/6
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0132 - accuracy: 0.5312
# Epoch 3/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5708 - accuracy: 0.9688
# Epoch 4/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3472 - accuracy: 0.9375
# Epoch 5/6
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1504 - accuracy: 1.0000
# Epoch 6/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0584 - accuracy: 1.0000
# Epoch 1/6
# 2/2 [==============================] - 2s 12ms/step - loss: 2.0562 - accuracy: 0.2812
# Epoch 2/6
# 2/2 [==============================] - 0s 9ms/step - loss: 1.2487 - accuracy: 0.3750
# Epoch 3/6
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0157 - accuracy: 0.6875
# Epoch 4/6
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7597 - accuracy: 0.9375
# Epoch 5/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5198 - accuracy: 0.9688
# Epoch 6/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2889 - accuracy: 0.9375
# Epoch 1/6
# 2/2 [==============================] - 1s 10ms/step - loss: 1.5868 - accuracy: 0.3750
# Epoch 2/6
# 2/2 [==============================] - 0s 7ms/step - loss: 1.0810 - accuracy: 0.5000
# Epoch 3/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6332 - accuracy: 0.7917
# Epoch 4/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4135 - accuracy: 1.0000
# Epoch 5/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2196 - accuracy: 1.0000
# Epoch 6/6
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1036 - accuracy: 1.0000
# Epoch 1/6
# 2/2 [==============================] - 1s 11ms/step - loss: 1.8109 - accuracy: 0.2500
# Epoch 2/6
# 2/2 [==============================] - 0s 9ms/step - loss: 1.2372 - accuracy: 0.6250
# Epoch 3/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.9659 - accuracy: 0.5938
# Epoch 4/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6684 - accuracy: 0.8438
# Epoch 5/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4445 - accuracy: 0.9375
# Epoch 6/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2070 - accuracy: 1.0000
# Epoch 1/6
# 2/2 [==============================] - 1s 13ms/step - loss: 1.8436 - accuracy: 0.1250
# Epoch 2/6
# 2/2 [==============================] - 0s 10ms/step - loss: 1.7784 - accuracy: 0.3438
# Epoch 3/6
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0351 - accuracy: 0.6562
# Epoch 4/6
# 2/2 [==============================] - 0s 16ms/step - loss: 0.7620 - accuracy: 0.8750
# Epoch 5/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5154 - accuracy: 0.9375
# Epoch 6/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3630 - accuracy: 0.9062
# Epoch 5
# Found 88 images belonging to 4 classes.
# Epoch 1/6
# 2/2 [==============================] - 1s 9ms/step - loss: 1.5524 - accuracy: 0.1875
# Epoch 2/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9227 - accuracy: 0.6875
# Epoch 3/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5189 - accuracy: 0.9375
# Epoch 4/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2397 - accuracy: 0.9688
# Epoch 5/6
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1246 - accuracy: 1.0000
# Epoch 6/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0385 - accuracy: 1.0000
# Epoch 1/6
# 2/2 [==============================] - 1s 11ms/step - loss: 1.6827 - accuracy: 0.2500
# Epoch 2/6
# 2/2 [==============================] - 0s 11ms/step - loss: 1.2179 - accuracy: 0.4375
# Epoch 3/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9323 - accuracy: 0.6562
# Epoch 4/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5027 - accuracy: 0.9375
# Epoch 5/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3758 - accuracy: 0.9375
# Epoch 6/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1900 - accuracy: 0.9688
# Epoch 1/6
# 2/2 [==============================] - 1s 10ms/step - loss: 1.5966 - accuracy: 0.1667
# Epoch 2/6
# 2/2 [==============================] - 0s 10ms/step - loss: 1.1736 - accuracy: 0.5000
# Epoch 3/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6093 - accuracy: 0.8750
# Epoch 4/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3360 - accuracy: 0.9583
# Epoch 5/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1934 - accuracy: 1.0000
# Epoch 6/6
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0718 - accuracy: 1.0000
# Epoch 1/6
# 2/2 [==============================] - 1s 10ms/step - loss: 1.8895 - accuracy: 0.3750
# Epoch 2/6
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1252 - accuracy: 0.6250
# Epoch 3/6
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9040 - accuracy: 0.6250
# Epoch 4/6
# ...
# Epoch 5/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2437 - accuracy: 0.9375
# Epoch 6/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1056 - accuracy: 0.9688
# Epoch 7/10
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0596 - accuracy: 0.9688
# Epoch 8/10
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 9/10
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 10/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 7
# Found 88 images belonging to 4 classes.
# Epoch 1/10
# 5/5 [==============================] - 1s 6ms/step - loss: 2.3007 - accuracy: 0.3750
# Epoch 2/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.9344 - accuracy: 0.7188
# Epoch 3/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6774 - accuracy: 0.8750
# Epoch 4/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2866 - accuracy: 0.8750
# Epoch 5/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0843 - accuracy: 1.0000
# Epoch 6/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0252 - accuracy: 1.0000
# Epoch 7/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 8/10
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 9/10
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 10/10
# 5/5 [==============================] - 0s 5ms/step - loss: 4.6983e-04 - accuracy: 1.0000
# Epoch 1/10
# 5/5 [==============================] - 2s 6ms/step - loss: 1.8708 - accuracy: 0.1875
# Epoch 2/10
# 5/5 [==============================] - 0s 5ms/step - loss: 1.1662 - accuracy: 0.4375
# Epoch 3/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.8255 - accuracy: 0.8125
# Epoch 4/10
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3166 - accuracy: 0.9688
# Epoch 5/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1071 - accuracy: 0.9375
# Epoch 6/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0366 - accuracy: 1.0000
# Epoch 7/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 8/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 9/10
# 5/5 [==============================] - 0s 5ms/step - loss: 5.8188e-04 - accuracy: 1.0000
# Epoch 10/10
# 5/5 [==============================] - 0s 5ms/step - loss: 3.2611e-04 - accuracy: 1.0000
# Epoch 1/10
# 5/5 [==============================] - 1s 7ms/step - loss: 1.6739 - accuracy: 0.4167
# Epoch 2/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7181 - accuracy: 0.9167
# Epoch 3/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2603 - accuracy: 1.0000
# Epoch 4/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0686 - accuracy: 1.0000
# Epoch 5/10
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 6/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 7/10
# 5/5 [==============================] - 0s 5ms/step - loss: 6.5086e-04 - accuracy: 1.0000
# Epoch 8/10
# 5/5 [==============================] - 0s 7ms/step - loss: 4.8613e-04 - accuracy: 1.0000
# Epoch 9/10
# 5/5 [==============================] - 0s 5ms/step - loss: 1.3155e-04 - accuracy: 1.0000
# Epoch 10/10
# 5/5 [==============================] - 0s 5ms/step - loss: 7.6553e-05 - accuracy: 1.0000
# Epoch 1/10
# 5/5 [==============================] - 1s 6ms/step - loss: 1.6109 - accuracy: 0.3125
# Epoch 2/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.8478 - accuracy: 0.6875
# Epoch 3/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4125 - accuracy: 0.8125
# Epoch 4/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1104 - accuracy: 1.0000
# Epoch 5/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 6/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 7/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0372 - accuracy: 1.0000
# Epoch 8/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 9/10
# 5/5 [==============================] - 0s 5ms/step - loss: 7.9778e-04 - accuracy: 1.0000
# Epoch 10/10
# 5/5 [==============================] - 0s 5ms/step - loss: 6.7403e-04 - accuracy: 1.0000
# Epoch 1/10
# 5/5 [==============================] - 2s 6ms/step - loss: 2.0217 - accuracy: 0.3438
# Epoch 2/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.9578 - accuracy: 0.8438
# Epoch 3/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5587 - accuracy: 0.9062
# Epoch 4/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2092 - accuracy: 0.9688
# Epoch 5/10
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1284 - accuracy: 0.9688
# Epoch 6/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0712 - accuracy: 0.9688
# Epoch 7/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0222 - accuracy: 1.0000
# Epoch 8/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0239 - accuracy: 1.0000
# Epoch 9/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 10/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 8
# Found 88 images belonging to 4 classes.
# Epoch 1/10
# 5/5 [==============================] - 2s 7ms/step - loss: 1.3101 - accuracy: 0.5312
# Epoch 2/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7167 - accuracy: 0.7188
# Epoch 3/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2457 - accuracy: 0.9688
# Epoch 4/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0750 - accuracy: 1.0000
# Epoch 5/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 6/10
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 7/10
# 5/5 [==============================] - 0s 5ms/step - loss: 9.7279e-04 - accuracy: 1.0000
# Epoch 8/10
# 5/5 [==============================] - 0s 5ms/step - loss: 9.2357e-05 - accuracy: 1.0000
# Epoch 9/10
# 5/5 [==============================] - 0s 8ms/step - loss: 1.0079e-04 - accuracy: 1.0000
# Epoch 10/10
# 5/5 [==============================] - 0s 5ms/step - loss: 1.1231e-04 - accuracy: 1.0000
# Epoch 1/10
# 5/5 [==============================] - 1s 5ms/step - loss: 1.4969 - accuracy: 0.4688
# Epoch 2/10
# 5/5 [==============================] - 0s 5ms/step - loss: 1.0241 - accuracy: 0.5000
# Epoch 3/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5510 - accuracy: 0.9062
# Epoch 4/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2755 - accuracy: 0.9375
# Epoch 5/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1147 - accuracy: 0.9688
# Epoch 6/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0411 - accuracy: 1.0000
# Epoch 7/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 8/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 9/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 10/10
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 1/10
# 5/5 [==============================] - 1s 6ms/step - loss: 1.8660 - accuracy: 0.4167
# Epoch 2/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.9203 - accuracy: 0.4583
# Epoch 3/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5082 - accuracy: 0.7917
# Epoch 4/10
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1967 - accuracy: 1.0000
# Epoch 5/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0426 - accuracy: 1.0000
# Epoch 6/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 7/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 8/10
# 5/5 [==============================] - 0s 5ms/step - loss: 4.6332e-04 - accuracy: 1.0000
# Epoch 9/10
# 5/5 [==============================] - 0s 6ms/step - loss: 2.0705e-04 - accuracy: 1.0000
# Epoch 10/10
# 5/5 [==============================] - 0s 5ms/step - loss: 9.7510e-05 - accuracy: 1.0000
# Epoch 1/10
# 5/5 [==============================] - 2s 6ms/step - loss: 1.2654 - accuracy: 0.5625
# Epoch 2/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6882 - accuracy: 0.9688
# Epoch 3/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1958 - accuracy: 0.9688
# Epoch 4/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0366 - accuracy: 1.0000
# Epoch 5/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 6/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 7/10
# 5/5 [==============================] - 0s 5ms/step - loss: 5.5333e-04 - accuracy: 1.0000
# Epoch 8/10
# 5/5 [==============================] - 0s 5ms/step - loss: 7.6962e-04 - accuracy: 1.0000
# Epoch 9/10
# 5/5 [==============================] - 0s 5ms/step - loss: 2.1713e-04 - accuracy: 1.0000
# Epoch 10/10
# 5/5 [==============================] - 0s 5ms/step - loss: 7.7840e-05 - accuracy: 1.0000
# Epoch 1/10
# 5/5 [==============================] - 1s 7ms/step - loss: 1.9306 - accuracy: 0.2812
# Epoch 2/10
# 5/5 [==============================] - 0s 5ms/step - loss: 1.1884 - accuracy: 0.4062
# Epoch 3/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.7244 - accuracy: 0.8125
# Epoch 4/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3697 - accuracy: 0.9062
# Epoch 5/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2439 - accuracy: 0.8750
# Epoch 6/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0762 - accuracy: 1.0000
# Epoch 7/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0818 - accuracy: 0.9688
# Epoch 8/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 9/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 10/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 9
# Found 88 images belonging to 4 classes.
# Epoch 1/10
# 5/5 [==============================] - 1s 6ms/step - loss: 1.9301 - accuracy: 0.4688
# Epoch 2/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.9175 - accuracy: 0.6875
# Epoch 3/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5104 - accuracy: 0.9375
# Epoch 4/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1576 - accuracy: 0.9688
# Epoch 5/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0690 - accuracy: 0.9688
# Epoch 6/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 7/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 8/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 9/10
# 5/5 [==============================] - 0s 5ms/step - loss: 7.7681e-04 - accuracy: 1.0000
# Epoch 10/10
# 5/5 [==============================] - 0s 5ms/step - loss: 4.7640e-04 - accuracy: 1.0000
# Epoch 1/10
# 5/5 [==============================] - 1s 6ms/step - loss: 1.5906 - accuracy: 0.3125
# Epoch 2/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.8533 - accuracy: 0.8125
# Epoch 3/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3614 - accuracy: 0.9062
# Epoch 4/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1209 - accuracy: 1.0000
# Epoch 5/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 6/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 7/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 8/10
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 9/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 10/10
# 5/5 [==============================] - 0s 5ms/step - loss: 6.6612e-04 - accuracy: 1.0000
# Epoch 1/10
# 5/5 [==============================] - 1s 5ms/step - loss: 1.6735 - accuracy: 0.2917
# Epoch 2/10
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8299 - accuracy: 0.6667
# Epoch 3/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3151 - accuracy: 0.9583
# Epoch 4/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0725 - accuracy: 1.0000
# Epoch 5/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 6/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 7/10
# 5/5 [==============================] - 0s 6ms/step - loss: 3.0357e-04 - accuracy: 1.0000
# Epoch 8/10
# 5/5 [==============================] - 0s 5ms/step - loss: 3.7409e-04 - accuracy: 1.0000
# Epoch 9/10
# 5/5 [==============================] - 0s 5ms/step - loss: 3.3810e-04 - accuracy: 1.0000
# Epoch 10/10
# 5/5 [==============================] - 0s 5ms/step - loss: 2.0412e-04 - accuracy: 1.0000
# Epoch 1/10
# 5/5 [==============================] - 1s 5ms/step - loss: 2.0678 - accuracy: 0.3438
# Epoch 2/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.8781 - accuracy: 0.7812
# Epoch 3/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4163 - accuracy: 0.9688
# Epoch 4/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1144 - accuracy: 0.9688
# Epoch 5/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0448 - accuracy: 0.9688
# Epoch 6/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 7/10
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 8/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 9/10
# 5/5 [==============================] - 0s 5ms/step - loss: 8.4171e-04 - accuracy: 1.0000
# Epoch 10/10
# 5/5 [==============================] - 0s 6ms/step - loss: 4.6536e-04 - accuracy: 1.0000
# Epoch 1/10
# 5/5 [==============================] - 1s 5ms/step - loss: 2.4268 - accuracy: 0.1875
# Epoch 2/10
# 5/5 [==============================] - 0s 5ms/step - loss: 1.1428 - accuracy: 0.7188
# Epoch 3/10
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8578 - accuracy: 0.8750
# Epoch 4/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4594 - accuracy: 0.8750
# Epoch 5/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2173 - accuracy: 0.9688
# Epoch 6/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1174 - accuracy: 0.9688
# Epoch 7/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0455 - accuracy: 1.0000
# Epoch 8/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 9/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 10/10
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 1.0000
# Saved model: Model_5_10.h5
# Loaded model from disk: Model_5_10.h5
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# The Loss = [2.4267873764038086, 1.1427539587020874, 0.8577836155891418, 0.4594382345676422, 0.21730343997478485, 0.11744896322488785, 0.045464012771844864, 0.0065767234191298485, 0.003117271699011326, 0.002476644469425082]
# Accuracy: 0.75
# --------------

# %% [markdown]
# f) Create a final dataframe that combines the accuracy across each combination.

# %%
df[['Steps', 'Epochs', 'Accuracy']].style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_305a9" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_305a9_level0_col0" class="col_heading level0 col0" >Steps</th>
#       <th id="T_305a9_level0_col1" class="col_heading level0 col1" >Epochs</th>
#       <th id="T_305a9_level0_col2" class="col_heading level0 col2" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_305a9_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_305a9_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_305a9_row0_col2" class="data row0 col2" >0.250000</td>
#     </tr>
#     <tr>
#       <td id="T_305a9_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_305a9_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_305a9_row1_col2" class="data row1 col2" >0.250000</td>
#     </tr>
#     <tr>
#       <td id="T_305a9_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_305a9_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_305a9_row2_col2" class="data row2 col2" >0.625000</td>
#     </tr>
#     <tr>
#       <td id="T_305a9_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_305a9_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_305a9_row3_col2" class="data row3 col2" >0.500000</td>
#     </tr>
#     <tr>
#       <td id="T_305a9_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_305a9_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_305a9_row4_col2" class="data row4 col2" >0.875000</td>
#     </tr>
#     <tr>
#       <td id="T_305a9_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_305a9_row5_col1" class="data row5 col1" >6</td>
#       <td id="T_305a9_row5_col2" class="data row5 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_305a9_row6_col0" class="data row6 col0" >3</td>
#       <td id="T_305a9_row6_col1" class="data row6 col1" >7</td>
#       <td id="T_305a9_row6_col2" class="data row6 col2" >0.750000</td>
#     </tr>
#     <tr>
#       <td id="T_305a9_row7_col0" class="data row7 col0" >3</td>
#       <td id="T_305a9_row7_col1" class="data row7 col1" >8</td>
#       <td id="T_305a9_row7_col2" class="data row7 col2" >0.750000</td>
#     </tr>
#     <tr>
#       <td id="T_305a9_row8_col0" class="data row8 col0" >5</td>
#       <td id="T_305a9_row8_col1" class="data row8 col1" >9</td>
#       <td id="T_305a9_row8_col2" class="data row8 col2" >0.875000</td>
#     </tr>
#     <tr>
#       <td id="T_305a9_row9_col0" class="data row9 col0" >5</td>
#       <td id="T_305a9_row9_col1" class="data row9 col1" >10</td>
#       <td id="T_305a9_row9_col2" class="data row9 col2" >0.750000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_1355e" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_1355e_level0_col0" class="col_heading level0 col0" >Steps</th>
#       <th id="T_1355e_level0_col1" class="col_heading level0 col1" >Epochs</th>
#       <th id="T_1355e_level0_col2" class="col_heading level0 col2" >Accuracy</th>
#       <th id="T_1355e_level0_col3" class="col_heading level0 col3" >Train Loss</th>
#       <th id="T_1355e_level0_col4" class="col_heading level0 col4" >Train Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1355e_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_1355e_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_1355e_row0_col2" class="data row0 col2" >0.250000</td>
#       <td id="T_1355e_row0_col3" class="data row0 col3" >1.427033</td>
#       <td id="T_1355e_row0_col4" class="data row0 col4" >0.031250</td>
#     </tr>
#     <tr>
#       <td id="T_1355e_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_1355e_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_1355e_row1_col2" class="data row1 col2" >0.250000</td>
#       <td id="T_1355e_row1_col3" class="data row1 col3" >2.099864</td>
#       <td id="T_1355e_row1_col4" class="data row1 col4" >0.250000</td>
#     </tr>
#     <tr>
#       <td id="T_1355e_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_1355e_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_1355e_row2_col2" class="data row2 col2" >0.625000</td>
#       <td id="T_1355e_row2_col3" class="data row2 col3" >0.968235</td>
#       <td id="T_1355e_row2_col4" class="data row2 col4" >0.531250</td>
#     </tr>
#     <tr>
#       <td id="T_1355e_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_1355e_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_1355e_row3_col2" class="data row3 col2" >0.500000</td>
#       <td id="T_1355e_row3_col3" class="data row3 col3" >0.801228</td>
#       <td id="T_1355e_row3_col4" class="data row3 col4" >0.781250</td>
#     </tr>
#     <tr>
#       <td id="T_1355e_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_1355e_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_1355e_row4_col2" class="data row4 col2" >0.875000</td>
#       <td id="T_1355e_row4_col3" class="data row4 col3" >0.375988</td>
#       <td id="T_1355e_row4_col4" class="data row4 col4" >0.906250</td>
#     </tr>
#     <tr>
#       <td id="T_1355e_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_1355e_row5_col1" class="data row5 col1" >6</td>
#       <td id="T_1355e_row5_col2" class="data row5 col2" >1.000000</td>
#       <td id="T_1355e_row5_col3" class="data row5 col3" >0.604526</td>
#       <td id="T_1355e_row5_col4" class="data row5 col4" >0.875000</td>
#     </tr>
#     <tr>
#       <td id="T_1355e_row6_col0" class="data row6 col0" >3</td>
#       <td id="T_1355e_row6_col1" class="data row6 col1" >7</td>
#       <td id="T_1355e_row6_col2" class="data row6 col2" >0.750000</td>
#       <td id="T_1355e_row6_col3" class="data row6 col3" >0.020536</td>
#       <td id="T_1355e_row6_col4" class="data row6 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_1355e_row7_col0" class="data row7 col0" >3</td>
#       <td id="T_1355e_row7_col1" class="data row7 col1" >8</td>
#       <td id="T_1355e_row7_col2" class="data row7 col2" >0.750000</td>
#       <td id="T_1355e_row7_col3" class="data row7 col3" >0.049375</td>
#       <td id="T_1355e_row7_col4" class="data row7 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_1355e_row8_col0" class="data row8 col0" >5</td>
#       <td id="T_1355e_row8_col1" class="data row8 col1" >9</td>
#       <td id="T_1355e_row8_col2" class="data row8 col2" >0.875000</td>
#       <td id="T_1355e_row8_col3" class="data row8 col3" >0.001152</td>
#       <td id="T_1355e_row8_col4" class="data row8 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_1355e_row9_col0" class="data row9 col0" >5</td>
#       <td id="T_1355e_row9_col1" class="data row9 col1" >10</td>
#       <td id="T_1355e_row9_col2" class="data row9 col2" >0.750000</td>
#       <td id="T_1355e_row9_col3" class="data row9 col3" >0.002477</td>
#       <td id="T_1355e_row9_col4" class="data row9 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Conceptual Questions:

# %% [markdown]
# 4. Discuss the effect of the following on accuracy and loss (train & test):
# - Increasing the steps_per_epoch
# - Increasing the number of epochs
#
#
#
# > We can see that increasing both the steps_per_epoch and epochs generally improves the training accuracy and reduces the training loss. This indicates that the model is learning more from the data as it is being exposed to it for longer periods of time. However, the effect on the test accuracy and loss is more mixed, with some increases and decreases observed.
#
# > Specifically, we can observe that the training accuracy consistently improves as the number of steps_per_epoch and epochs increase. Similarly, the training loss consistently reduces as the number of steps_per_epoch and epochs increase.
#
# > On the other hand, the effect on the test accuracy and loss is more varied. For example, increasing from (1,1) to (1,3) improves the test accuracy, but increasing from (1,3) to (2,4) actually reduces the test accuracy. Similarly, increasing from (1,2) to (2,6) dramatically improves the test accuracy, but increasing from (3,7) to (5,9) has a smaller effect. This suggests that simply increasing the steps_per_epoch and epochs may not always lead to better performance on the test set, and that the optimal values may depend on the specific dataset and model being used.

# %% [markdown]
# 5. Name two uses of zero padding in CNN.
# Zero padding is a technique used in convolutional neural networks (CNNs) that involves adding zeros around the borders of an input image or feature map. This technique can be used for two main purposes.
# - Firstly, it can help to preserve the spatial dimensions of an input image or feature map as it is passed through convolutional layers, which can be useful for tasks such as object detection and segmentation.
# - Secondly, it can help to prevent the loss of information at the borders of an input image or feature map during convolution, which can be important for maintaining the overall quality and accuracy of a CNN's output.

# %% [markdown]
# 6. What is the use of a 1 x 1 kernel in CNN? <br>
# The use of a 1 x 1 kernel in CNNs is to perform dimensionality reduction and compression on the feature maps. This kernel acts like a filter and is applied to each pixel of the input image, allowing the network to combine information from different channels at each location. By reducing the number of channels in a feature map, a 1 x 1 convolution can help to reduce the computational cost of the network while also improving its performance by making it more robust to overfitting. Additionally, a 1 x 1 convolution can be used as a bottleneck layer, where it is placed between layers with a high number of filters to reduce the number of features and computational cost without losing too much information.

# %% [markdown]
# 7. What are the advantages of a CNN over a fully connected DNN for this image classification problem?
# - Parameter sharing: In CNNs, the same filters are used across the entire image, which means that the number of parameters is significantly reduced compared to a fully connected DNN. This makes CNNs more efficient to train and requires less memory.
#
# - Translation invariance: CNNs can detect features regardless of their position in the image. This is achieved by using filters that slide across the entire image, which enables CNNs to capture the spatial dependencies between pixels.
#
# - Local receptive fields: CNNs use local receptive fields, which allow them to capture the local structure of the image. This means that the filters only operate on a small region of the image at a time, which helps to preserve the spatial structure of the image.
#
# - Hierarchical representation: CNNs are able to learn hierarchical representations of the image, where low-level features are combined to form higher-level features. This enables CNNs to capture complex patterns in the image and leads to improved classification accuracy.
#
# > Overall, CNNs are a powerful tool for image classification due to their ability to capture spatial dependencies and learn hierarchical representations of the image.
